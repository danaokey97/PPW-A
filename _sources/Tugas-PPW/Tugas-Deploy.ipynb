# %% [markdown]
# # **Tugas Deploy**

# %% [markdown]
# ### 1. Klasifikasi Logistic Regression Tanpa Reduksi Dimensi :
# ### https://huggingface.co/spaces/danaokey97/klasifikasi-logrec

# %% [markdown]
# ### 2. Klasifikasi Logistic Regression Menggunakan Reduksi Dimensi (SVD) :
#  ### https://huggingface.co/spaces/danaokey97/SVD-Logrec-Klasifikasi

# %% [markdown]
# ### 3. Graph :
# ### https://huggingface.co/spaces/danaokey97/PPW-Graph

# %% [markdown]
# ### 4. Clustering Fuzzy C Means :
# ### https://huggingface.co/spaces/danaokey97/Fuzzy-cm-berita
