# %% [markdown]
# # 1. Klasifikasi Logistic Regression Tanpa Reduksi Dimensi : [link text](https://)

# %% [markdown]
# # 2. Klasifikasi Logistic Regression Menggunakan Reduksi Dimensi (SVD) : [link text](https://)

# %% [markdown]
# # 3. Graph : [link text](https://)
